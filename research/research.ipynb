# %%
# %pip install python-box
from box import ConfigBox
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
example=ConfigBox({"key1": "Value1", "Key2": "Value2"})
example.key1
# Out:
# 'Value1'

# %%
def get_multiples(x:int,y:int) -> int:
    return x*y

# %%
get_multiples(2,2)
# Out:
# 4

# %%
get_multiples(2,"_4")
# Out:
# '_4_4'

# %%
# %pip install ensure
from ensure import ensure_annotations

@ensure_annotations
def get_multiples(x:int,y:int) -> int:
    return x*y
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
get_multiples(2,"40")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_multiples(2,"40")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/ensure/main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_multiples at 0x756edcb96840> does not match annotation type <class 'int'>
